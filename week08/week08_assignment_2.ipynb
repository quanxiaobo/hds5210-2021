# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

response = requests.get('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
div = soup.find_all('div', {"class":"col-md-8"})[0]
for hospital_list in div.find_all('ul'):
    state = hospital_list.previous_sibling.previous_sibling.string
    for hospital in hospital_list.find_all('li'):
        print(state, hospital.text)
# Out:
# Arizona Banner - University Medical Center Phoenix
# Arizona Banner - University Medical Center South
# Arizona Banner - University Medical Center Tucson
# Arizona Banner Baywood Medical Center
# Arizona Banner Behavioral Health Hospital
# Arizona Banner Boswell Medical Center
# Arizona Banner Casa Grande Medical Center
# Arizona Banner Del E. Webb Medical Center
# Arizona Banner Desert Medical Center/Cardon Children's Medical Center
# Arizona Banner Estrella Medical Center
# Arizona Banner Gateway Medical Center/Banner MD Anderson Cancer Center
# Arizona Banner Goldfield Medical Center
# Arizona Banner Heart Hospital
# Arizona Banner Ironwood Medical Center
# Arizona Banner Ocotillo Medical Center
# Arizona Banner Payson Medical Center
# Arizona Banner Thunderbird Medical Center
# Arizona Page Hospital
# California Banner Lassen Medical Center
# Colorado Banner Fort Collins Medical Center
# Colorado McKee Medical Center
# Colorado North Colorado Medical Center
# Colorado Sterling Regional Medical Center
# Colorado East Morgan County Hospital
# Nebraska Ogallala Community Hospital
# Nevada Banner Churchill Community Hospital
# Wyoming Banner Wyoming Medical Center
# Wyoming Community Hospital
# Wyoming Washakie Medical Center
# Wyoming Platte County Memorial Hospital
# State-Specific Regulations Arizona
# State-Specific Regulations California
# State-Specific Regulations Colorado
# State-Specific Regulations Nebraska
# State-Specific Regulations Nevada
# State-Specific Regulations Wyoming

# %% [markdown]
# ---
#
# ### 33.2 Using Pandas to Read Tables
#
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Diagnosis-related_group')
len(tables)
# Out:
# 5

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please updat...
# 2 NaN  This article needs additional citations for ve...
# **************TABLE 1
#     0                                                  1
# 0 NaN  This article needs to be updated. Please updat...
# **************TABLE 2
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
# **************TABLE 3
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8  \
# 0                                         Description
# 1                              Average length of stay
# 2                      Large urban labor-related rate
# 3                       Large urban non-labor-related
# 4                                          Wage index
# 5   Standard Federal Rate: labor * wage index + no...
# 6                     DRG relative weight (RW) factor
# 7    Weighted payment: Standard Federal Rate * DRG RW
# 8                Disproportionate Share Payment (DSH)
# 9                    Indirect medical education (IME)
# 10                   Total cost outlier reimbursement
# 11  Total operating payment: Weighted payment * (1...
#
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8.1
# 0                                               Value
# 1                                             3.8[16]
# 2                                           $2,809.18
# 3                                           $1,141.85
# 4                                              1.4193
# 5                                           $5,128.92
# 6                                              1.8128
# 7                                           $9,297.71
# 8                                              0.1413
# 9                                              0.0744
# 10                                                 $0
# 11                                         $11,303.23
# **************TABLE 4
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %%
drgs = tables[4]
drgs
# Out:
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Extract the reference list from a PMC free article page
# The output is a list of dictionaries
# Each dictionary contains the information of one reference 
from bs4 import BeautifulSoup
import requests
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }
article_link = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2815940/'
response = requests.get(article_link, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Extract reference information and compile the dictinary
div = soup.find_all('div', {"id":"reference-list"})[0]
import re
ref_list = []
for ref in div.find_all('li'):
    if ref.find('span',{"class":"element-citation"}).find('a', text="PubMed") == None:
        pmid = ''
    else:
        pmid = ref.find('span',{"class":"element-citation"}).find('a', text="PubMed")['href'].split("/")[-1]
    if ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-vol"}) == None:
        pub_type = 'book'
        author = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).previous_sibling.split('.')[0].strip()
        title = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).text.strip(". ")
        year = re.split('[;.]', ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).next_sibling)[1].strip('.; ')
        publisher = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).next_sibling.split(';')[0].strip('.; ')
        ref_list.append({'type':pub_type,
                         'author':author,
                         'title':title,
                         'year':year,
                         'publisher':publisher,
                         'PMID':pmid})  
    else:
        pub_type = 'article'
        author = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).parent.previous_sibling.split('.')[0].strip()
        title = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).parent.previous_sibling.split('.')[1].strip()
        journal = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-journal"}).text.strip(". ")
        year = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-vol"}).previous_sibling.strip('; ')
        vol = ref.find('span',{"class":"element-citation"}).find('span',{"class":"ref-vol"}).text.strip(". ")
        pages = ref.find('span',{"class":"element-citation"}).text.split(".")[-2].strip().split(":")[-1]
        ref_list.append({'type':pub_type,
                         'author':author,
                         'title':title,
                         'journal':journal,
                         'year':year,
                         'vol':vol,
                         'pages':pages,
                         'PMID':pmid})

# %%
 ref_list
# Out:
# [{'type': 'article',
#   'author': 'Addessi E, Mancini A, Crescimbene L, Padoa-Schioppa C, Visalberghi E',
#   'title': 'Preference transitivity and symbolic representation in capuchin monkeys (cebus apella)',
#   'journal': 'PLoS ONE',
#   'year': '2008',
#   'vol': '3',
#   'pages': 'e2414',
#   'PMID': '18545670'},
#  {'type': 'article',
#   'author': 'Alajouanine T',
#   'title': 'Aphasia and artistic realization',
#   'journal': 'Brain',
#   'year': '1948',
#   'vol': '71',
#   'pages': '229–241',
#   'PMID': '18099548'},
#  {'type': 'book',
#   'author': 'Bahn PG',
#   'title': 'The Cambridge Illustrated History of Prehistoric Art',
#   'year': '1998',
#   'publisher': 'Cambridge: Cambridge University Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Behar DM, Villems R, Soodyall H, et al',
#   'title': 'The dawn of human matrilineal diversity',
#   'journal': 'Am J Hum Gen',
#   'year': '2008',
#   'vol': '82',
#   'pages': '1130–1140',
#   'PMID': '18439549'},
#  {'type': 'article',
#   'author': 'Berridge KC',
#   'title': 'Pleasures of the brain',
#   'journal': 'Brain Cogn',
#   'year': '2003',
#   'vol': '52',
#   'pages': '106–128',
#   'PMID': '12812810'},
#  {'type': 'article',
#   'author': 'Blanke O, Ortigue S, Landis T',
#   'title': 'Colour neglect in an artist',
#   'journal': 'Lancet',
#   'year': '2003',
#   'vol': '361',
#   'pages': '264',
#   'PMID': '12547582'},
#  {'type': 'book',
#   'author': 'Bogousslavsky J, Boller F, editors',
#   'title': 'Frontiers in Neurological Neuroscience',
#   'year': '2005',
#   'publisher': 'Basel: Karger',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Boller F, Sinforiani E, Mazzucchi A',
#   'title': 'Preserved painting abilities after a stroke',
#   'journal': 'Funct Neurol',
#   'year': '2005',
#   'vol': '20',
#   'pages': '151–155',
#   'PMID': '16483452'},
#  {'type': 'article',
#   'author': 'Burgdorf J, Panksepp J',
#   'title': 'The neurobiology of positive emotions',
#   'journal': 'Neurosci Biobehav Rev',
#   'year': '2006',
#   'vol': '30',
#   'pages': '173–187',
#   'PMID': '16099508'},
#  {'type': 'article',
#   'author': 'Carstairs-McCarthy A',
#   'title': 'Language: many perspectives, no consensus',
#   'journal': 'Science',
#   'year': '2004',
#   'vol': '303',
#   'pages': '1299–1300',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'Corballis MC',
#   'title': 'From Hand to Mouth: The Origins of Language',
#   'year': '2003',
#   'publisher': 'Princeton: Princeton University Press',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'Cronin H',
#   'title': 'The Ant and the Peacock',
#   'year': '1992',
#   'publisher': 'Cambridge: Cambridge University Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Cummings JL, Miller BL, Christensen DD, Cherry D',
#   'title': "Creativity and dementia: Emerging diagnostic and treatment methods for Alzheimer's disease",
#   'journal': 'CNS Spectrum',
#   'year': '2008',
#   'vol': '13',
#   'pages': '1–20',
#   'PMID': '18264030'},
#  {'type': 'article',
#   'author': 'Damasio A',
#   'title': 'Brain trust',
#   'journal': 'Nature',
#   'year': '2005',
#   'vol': '435',
#   'pages': '571–572',
#   'PMID': '15931200'},
#  {'type': 'book',
#   'author': 'Darwin C',
#   'title': 'The Descent of Man, and Selection in Relation to Sex',
#   'year': '1871',
#   'publisher': 'London: John Murray',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'De Renzi E',
#   'title': 'Disorders of Space Exploration and Cognition',
#   'year': '1982',
#   'publisher': 'New York: Wiley',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'd’Errico F, Henshilwood C, Lawson G, et al',
#   'title': 'Archaeological evidence for the emergence of language, symbolism, and music – an alternative multidisciplinary perspective',
#   'journal': 'J World Prehis',
#   'year': '2003',
#   'vol': '17',
#   'pages': '1–70',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'de Waal FBM, Tyack PL, editors',
#   'title': 'Animal Social Complexity: Intelligence, Culture, and Individualized Societies',
#   'year': '2003',
#   'publisher': 'Cambridge, Mass: Harvard University Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Drago V, Crucian GP, Foster PS, et al',
#   'title': 'Lewy body dementia and creativity: Case report',
#   'journal': 'Neuropsychologia',
#   'year': '2006',
#   'vol': '44',
#   'pages': '3011–3015',
#   'PMID': '16930639'},
#  {'type': 'article',
#   'author': 'Fornazzari LR',
#   'title': "Preserved painting creativity in an artist with Alzheimer's disease",
#   'journal': 'Eur J Neurol',
#   'year': '2005',
#   'vol': '12',
#   'pages': '419–424',
#   'PMID': '15885044'},
#  {'type': 'article',
#   'author': 'Hauser MD, Bever T',
#   'title': 'A biolinguistic agenda',
#   'journal': 'Science',
#   'year': '2008',
#   'vol': '232',
#   'pages': '1057–1059',
#   'PMID': '19008433'},
#  {'type': 'article',
#   'author': 'Jacobsen T, Schubotz RI, Hofel L, Von Cramon DY',
#   'title': 'Brain correlates of aesthetic judgment of beauty',
#   'journal': 'NeuroImage',
#   'year': '2006',
#   'vol': '29',
#   'pages': '276–286',
#   'PMID': '16087351'},
#  {'type': 'article',
#   'author': 'Kawabata H, Zeki S',
#   'title': 'Neural correlates of beauty',
#   'journal': 'J Neurophys',
#   'year': '2004',
#   'vol': '91',
#   'pages': '1699–1705',
#   'PMID': '15010496'},
#  {'type': 'book',
#   'author': 'Klein RG',
#   'title': 'The Human Career: Human Biological and Cultural Origins',
#   'year': '1999',
#   'publisher': 'Chicago: University of Chicago Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Kosfeld M, Heinrichs N, Zak PJ, Fischbacher U, Fehr E',
#   'title': 'Oxytocin increases trust in humans',
#   'journal': 'Nature',
#   'year': '2005',
#   'vol': '435',
#   'pages': '673–676',
#   'PMID': '15931222'},
#  {'type': 'book',
#   'author': 'Langer SK',
#   'title': 'Philosophical Sketches',
#   'year': '1962',
#   'publisher': 'Baltimore: The Johns Hopkins Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Leknes S, Tracey I',
#   'title': 'A common neurobiology for pain and pleasure',
#   'journal': 'Nat Rev Neurosci',
#   'year': '2008',
#   'vol': '9',
#   'pages': '314–320',
#   'PMID': '18354400'},
#  {'type': 'book',
#   'author': 'Lewis-Williams D',
#   'title': 'The Mind in the Cave: Consciousness and the Origins of Art',
#   'year': '2002',
#   'publisher': 'London: Thames and Hudson',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Lieberman P',
#   'title': 'The evolution of human speech: Its anatomical and neural bases',
#   'journal': 'Curr Anthro',
#   'year': '2007',
#   'vol': '48',
#   'pages': '39–66',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'McBrearty S, Brooks AS',
#   'title': "The revolution that wasn't: A new interpretation of the origin of modern human behavior",
#   'journal': 'J Hum Evol',
#   'year': '2000',
#   'vol': '39',
#   'pages': '453–563',
#   'PMID': '11102266'},
#  {'type': 'article',
#   'author': 'McBrearty S, Stringer C',
#   'title': 'The coast in colour',
#   'journal': 'Nature',
#   'year': '2007',
#   'vol': '449',
#   'pages': '793–794',
#   'PMID': '17943109'},
#  {'type': 'book',
#   'author': 'McNeill D',
#   'title': 'Hand and Mind: What Gestures Reveal about Thought',
#   'year': '1992',
#   'publisher': 'Chicago: Chicago University Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Meadows JC',
#   'title': 'Disturbed perception of colour associated with localized cerebral lesions',
#   'journal': 'Brain',
#   'year': '1974',
#   'vol': '97',
#   'pages': '615–632',
#   'PMID': '4547992'},
#  {'type': 'article',
#   'author': 'Mellars P',
#   'title': 'Going East: New genetic and archaeological perspectives on the modern human colonization of Eurasia',
#   'journal': 'Science',
#   'year': '2006',
#   'vol': '313',
#   'pages': '796–800',
#   'PMID': '16902130'},
#  {'type': 'article',
#   'author': 'Miceli G, Fouch E, Capasso R, Shelton JR, Tomaiuolo F, Caramazza A',
#   'title': 'The dissociation of color from form and function knowledge',
#   'journal': 'Nat Neurosci',
#   'year': '2001',
#   'vol': '4',
#   'pages': '662–667',
#   'PMID': '11369950'},
#  {'type': 'article',
#   'author': 'Miller BL, Ponton M, Benson FD, Cummings JL, Mena I',
#   'title': 'Enhanced artistic creativity with temporal lobe degeneration',
#   'journal': 'Lancet',
#   'year': '1996',
#   'vol': '348',
#   'pages': '1744–1745',
#   'PMID': '8973469'},
#  {'type': 'article',
#   'author': 'Miller BL, Cummings J, Mishkin F, et al',
#   'title': 'Emergence of artistic talent in frontotemporal dementia',
#   'journal': 'Neurology',
#   'year': '1998',
#   'vol': '51',
#   'pages': '978–981',
#   'PMID': '9781516'},
#  {'type': 'book',
#   'author': 'Miller GF',
#   'title': 'The Mating Mind: How Sexual Choice Shaped the Evolution of Human Nature',
#   'year': '2000',
#   'publisher': 'New York: Doubleday',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Miller GF',
#   'title': 'Aesthetic fitness: How sexual selection shaped artistic virtuosity as a fitness indicator and aesthetic preferences as mate choice criteria',
#   'journal': 'Bull Psycho Arts',
#   'year': '2001',
#   'vol': '2',
#   'pages': '20–25',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Morgan LE, Renne PR',
#   'title': "Diachronous dawn of Africa's middle stone age: New 40Ar/39Ar ages from the Ethiopian Rift",
#   'journal': 'Geology',
#   'year': '2008',
#   'vol': '36',
#   'pages': '967–970',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Nadal M, Munar E, Capó MA, Rosselló J, Cela-Conde CJ',
#   'title': 'Towards a framework for the study of the neural correlates of aesthetic preference',
#   'journal': 'Spat Vis',
#   'year': '2008',
#   'vol': '21',
#   'pages': '379–396',
#   'PMID': '18534110'},
#  {'type': 'article',
#   'author': 'Nathan J',
#   'title': 'The painter and handicapped vision',
#   'journal': 'Clin Exp Optom',
#   'year': '2002',
#   'vol': '85',
#   'pages': '309–314',
#   'PMID': '12366353'},
#  {'type': 'article',
#   'author': 'Olds J',
#   'title': 'Pleasure center in the brain',
#   'journal': 'Sci American',
#   'year': '1956',
#   'vol': '195',
#   'pages': '105–116',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Panksepp J',
#   'title': 'Affective consciousness: Core emotional feelings in animals and humans',
#   'journal': 'Conscious Cogn',
#   'year': '2005',
#   'vol': '14',
#   'pages': '30–80',
#   'PMID': '15766890'},
#  {'type': 'book',
#   'author': 'Patel AD',
#   'title': 'Music, Language and the Brain',
#   'year': '2007',
#   'publisher': 'New York: Oxford University Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Peretz I',
#   'title': 'The nature of music from a biological perspective',
#   'journal': 'Cognition',
#   'year': '2006',
#   'vol': '100',
#   'pages': '1–32',
#   'PMID': '16487953'},
#  {'type': 'article',
#   'author': 'Phillips H',
#   'title': 'The pleasure seekers',
#   'journal': 'New Scientist',
#   'year': '2003',
#   'vol': '180',
#   'pages': '36–40',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Ravin JG',
#   'title': 'The visual difficulties of selected artists and limitations of ophthalmological care during the 19th and 20th centuries',
#   'journal': 'Trans Am Ophthalmol Soc',
#   'year': '2008',
#   'vol': '106',
#   'pages': '402–425',
#   'PMID': '19277248'},
#  {'type': 'article',
#   'author': 'Relethford JH',
#   'title': 'Genetic evidence and the modern human origins debate',
#   'journal': 'Heredity',
#   'year': '2008',
#   'vol': '100',
#   'pages': '555–563',
#   'PMID': '18322457'},
#  {'type': 'article',
#   'author': 'Rolls ET, Grabenhorst F',
#   'title': 'The orbitofrontal cortex and beyond: From affect to decision-making',
#   'journal': 'Prog Neurobio',
#   'year': '2008',
#   'vol': '86',
#   'pages': '216–244',
#   'PMID': '18824074'},
#  {'type': 'book',
#   'author': 'Rose FC',
#   'title': 'Neurology of the Arts: Painting, Music, Literature',
#   'year': '2004',
#   'publisher': 'London: Imperial College Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Vartanian O, Goel V',
#   'title': 'Neuroanatomical correlates of aesthetic preference for paintings',
#   'journal': 'NeuroReport',
#   'year': '2004',
#   'vol': '15',
#   'pages': '893–897',
#   'PMID': '15073538'},
#  {'type': 'book',
#   'author': 'Wade N',
#   'title': 'Before the Dawn: Recovering the Lost History of Our Ancestors',
#   'year': '2006',
#   'publisher': 'New York: Penguin Press',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Wood B, Collard M',
#   'title': 'The human genus',
#   'journal': 'Science',
#   'year': '1999',
#   'vol': '284',
#   'pages': '65–71',
#   'PMID': '10102822'},
#  {'type': 'article',
#   'author': 'Zahavi A',
#   'title': 'Decorative patterns and the evolution of art',
#   'journal': 'New Scientist',
#   'year': '1978',
#   'vol': '19',
#   'pages': '182–184',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'Zaidel DW',
#   'title': 'Neuropsychology of Art: Neurological, Cognitive, and Evolutionary Perspectives',
#   'year': '2005',
#   'publisher': 'UK: Psychology Press',
#   'PMID': ''},
#  {'type': 'book',
#   'author': 'Zaidel DW',
#   'title': 'Neuroaesthetics',
#   'year': '2009',
#   'publisher': 'Amityville, NY: Baywood',
#   'PMID': ''},
#  {'type': 'article',
#   'author': 'Zak PJ, Kurzban R, Matzner WT',
#   'title': 'Oxytocin is associated with human trustworthiness',
#   'journal': 'Horm Behav',
#   'year': '2005',
#   'vol': '48',
#   'pages': '522–527',
#   'PMID': '16109416'},
#  {'type': 'article',
#   'author': 'Zeki S',
#   'title': 'A century of cerebral achromatopsia',
#   'journal': 'Brain',
#   'year': '1990',
#   'vol': '113',
#   'pages': '1721–1777',
#   'PMID': '2276043'}]

# %%
# Calculate frequency of journals in the refertence list
journal_list = []
journal_freq = {}
for ref in ref_list:
    if ref['type'] == 'article':
        journal_list.append(ref['journal'])
journal_set = set(journal_list)
for journal in journal_set:
    count = 0
    for name in journal_list:
        if name == journal:
            count += 1
    journal_freq[journal] = count
journal_freq_sorted = dict(sorted(journal_freq.items(), key=lambda item: (item[1], item[0]), reverse=True))
for j, c in journal_freq_sorted.items():
    print(j, c)
# Out:
# Science 4
# Nature 3
# Brain 3
# New Scientist 2
# Lancet 2
# Trans Am Ophthalmol Soc 1
# Spat Vis 1
# Sci American 1
# Prog Neurobio 1
# PLoS ONE 1
# Neurosci Biobehav Rev 1
# Neuropsychologia 1
# Neurology 1
# NeuroReport 1
# NeuroImage 1
# Nat Rev Neurosci 1
# Nat Neurosci 1
# J World Prehis 1
# J Neurophys 1
# J Hum Evol 1
# Horm Behav 1
# Heredity 1
# Geology 1
# Funct Neurol 1
# Eur J Neurol 1
# Curr Anthro 1
# Conscious Cogn 1
# Cognition 1
# Clin Exp Optom 1
# CNS Spectrum 1
# Bull Psycho Arts 1
# Brain Cogn 1
# Am J Hum Gen 1

# %%
# Calculate frequency of years of publication in the refertence list
year_list = []
year_freq = {}
for ref in ref_list:
    year_list.append(ref['year'])
year_set = set(year_list)
for year in year_set:
    count = 0
    for y in year_list:
        if y == year:
            count += 1
    year_freq[year] = count
year_freq_sorted = dict(sorted(year_freq.items(), key=lambda item: item[0], reverse=True))
for y, c in year_freq_sorted.items():
    print(y, c)
# Out:
# 2009 1
# 2008 10
# 2007 3
# 2006 6
# 2005 8
# 2004 4
# 2003 6
# 2002 2
# 2001 2
# 2000 2
# 1999 2
# 1998 2
# 1996 1
# 1992 2
# 1990 1
# 1982 1
# 1978 1
# 1974 1
# 1962 1
# 1956 1
# 1948 1
# 1871 1

# %%
# Print the reference list
for ref in ref_list:
    if ref['type']=='article':
        print(ref['author']+'. '+ref['title']+'. '+ref['journal']+'. '+ref['year']+';'+ref['vol']+':'+ref['pages']+'.')
    else:
        print(ref['author']+'. '+ref['title']+'. '+ref['publisher']+'; '+ref['year']+'.')
# Out:
# Addessi E, Mancini A, Crescimbene L, Padoa-Schioppa C, Visalberghi E. Preference transitivity and symbolic representation in capuchin monkeys (cebus apella). PLoS ONE. 2008;3:e2414.
# Alajouanine T. Aphasia and artistic realization. Brain. 1948;71:229–241.
# Bahn PG. The Cambridge Illustrated History of Prehistoric Art. Cambridge: Cambridge University Press; 1998.
# Behar DM, Villems R, Soodyall H, et al. The dawn of human matrilineal diversity. Am J Hum Gen. 2008;82:1130–1140.
# Berridge KC. Pleasures of the brain. Brain Cogn. 2003;52:106–128.
# Blanke O, Ortigue S, Landis T. Colour neglect in an artist. Lancet. 2003;361:264.
# Bogousslavsky J, Boller F, editors. Frontiers in Neurological Neuroscience. Basel: Karger; 2005.
# Boller F, Sinforiani E, Mazzucchi A. Preserved painting abilities after a stroke. Funct Neurol. 2005;20:151–155.
# Burgdorf J, Panksepp J. The neurobiology of positive emotions. Neurosci Biobehav Rev. 2006;30:173–187.
# Carstairs-McCarthy A. Language: many perspectives, no consensus. Science. 2004;303:1299–1300.
# Corballis MC. From Hand to Mouth: The Origins of Language. Princeton: Princeton University Press; 2003.
# Cronin H. The Ant and the Peacock. Cambridge: Cambridge University Press; 1992.
# Cummings JL, Miller BL, Christensen DD, Cherry D. Creativity and dementia: Emerging diagnostic and treatment methods for Alzheimer's disease. CNS Spectrum. 2008;13:1–20.
# Damasio A. Brain trust. Nature. 2005;435:571–572.
# Darwin C. The Descent of Man, and Selection in Relation to Sex. London: John Murray; 1871.
# De Renzi E. Disorders of Space Exploration and Cognition. New York: Wiley; 1982.
# d’Errico F, Henshilwood C, Lawson G, et al. Archaeological evidence for the emergence of language, symbolism, and music – an alternative multidisciplinary perspective. J World Prehis. 2003;17:1–70.
# de Waal FBM, Tyack PL, editors. Animal Social Complexity: Intelligence, Culture, and Individualized Societies. Cambridge, Mass: Harvard University Press; 2003.
# Drago V, Crucian GP, Foster PS, et al. Lewy body dementia and creativity: Case report. Neuropsychologia. 2006;44:3011–3015.
# Fornazzari LR. Preserved painting creativity in an artist with Alzheimer's disease. Eur J Neurol. 2005;12:419–424.
# Hauser MD, Bever T. A biolinguistic agenda. Science. 2008;232:1057–1059.
# Jacobsen T, Schubotz RI, Hofel L, Von Cramon DY. Brain correlates of aesthetic judgment of beauty. NeuroImage. 2006;29:276–286.
# Kawabata H, Zeki S. Neural correlates of beauty. J Neurophys. 2004;91:1699–1705.
# Klein RG. The Human Career: Human Biological and Cultural Origins. Chicago: University of Chicago Press; 1999.
# Kosfeld M, Heinrichs N, Zak PJ, Fischbacher U, Fehr E. Oxytocin increases trust in humans. Nature. 2005;435:673–676.
# Langer SK. Philosophical Sketches. Baltimore: The Johns Hopkins Press; 1962.
# Leknes S, Tracey I. A common neurobiology for pain and pleasure. Nat Rev Neurosci. 2008;9:314–320.
# Lewis-Williams D. The Mind in the Cave: Consciousness and the Origins of Art. London: Thames and Hudson; 2002.
# Lieberman P. The evolution of human speech: Its anatomical and neural bases. Curr Anthro. 2007;48:39–66.
# McBrearty S, Brooks AS. The revolution that wasn't: A new interpretation of the origin of modern human behavior. J Hum Evol. 2000;39:453–563.
# McBrearty S, Stringer C. The coast in colour. Nature. 2007;449:793–794.
# McNeill D. Hand and Mind: What Gestures Reveal about Thought. Chicago: Chicago University Press; 1992.
# Meadows JC. Disturbed perception of colour associated with localized cerebral lesions. Brain. 1974;97:615–632.
# Mellars P. Going East: New genetic and archaeological perspectives on the modern human colonization of Eurasia. Science. 2006;313:796–800.
# Miceli G, Fouch E, Capasso R, Shelton JR, Tomaiuolo F, Caramazza A. The dissociation of color from form and function knowledge. Nat Neurosci. 2001;4:662–667.
# Miller BL, Ponton M, Benson FD, Cummings JL, Mena I. Enhanced artistic creativity with temporal lobe degeneration. Lancet. 1996;348:1744–1745.
# Miller BL, Cummings J, Mishkin F, et al. Emergence of artistic talent in frontotemporal dementia. Neurology. 1998;51:978–981.
# Miller GF. The Mating Mind: How Sexual Choice Shaped the Evolution of Human Nature. New York: Doubleday; 2000.
# Miller GF. Aesthetic fitness: How sexual selection shaped artistic virtuosity as a fitness indicator and aesthetic preferences as mate choice criteria. Bull Psycho Arts. 2001;2:20–25.
# Morgan LE, Renne PR. Diachronous dawn of Africa's middle stone age: New 40Ar/39Ar ages from the Ethiopian Rift. Geology. 2008;36:967–970.
# Nadal M, Munar E, Capó MA, Rosselló J, Cela-Conde CJ. Towards a framework for the study of the neural correlates of aesthetic preference. Spat Vis. 2008;21:379–396.
# Nathan J. The painter and handicapped vision. Clin Exp Optom. 2002;85:309–314.
# Olds J. Pleasure center in the brain. Sci American. 1956;195:105–116.
# Panksepp J. Affective consciousness: Core emotional feelings in animals and humans. Conscious Cogn. 2005;14:30–80.
# Patel AD. Music, Language and the Brain. New York: Oxford University Press; 2007.
# Peretz I. The nature of music from a biological perspective. Cognition. 2006;100:1–32.
# Phillips H. The pleasure seekers. New Scientist. 2003;180:36–40.
# Ravin JG. The visual difficulties of selected artists and limitations of ophthalmological care during the 19th and 20th centuries. Trans Am Ophthalmol Soc. 2008;106:402–425.
# Relethford JH. Genetic evidence and the modern human origins debate. Heredity. 2008;100:555–563.
# Rolls ET, Grabenhorst F. The orbitofrontal cortex and beyond: From affect to decision-making. Prog Neurobio. 2008;86:216–244.
# Rose FC. Neurology of the Arts: Painting, Music, Literature. London: Imperial College Press; 2004.
# Vartanian O, Goel V. Neuroanatomical correlates of aesthetic preference for paintings. NeuroReport. 2004;15:893–897.
# Wade N. Before the Dawn: Recovering the Lost History of Our Ancestors. New York: Penguin Press; 2006.
# Wood B, Collard M. The human genus. Science. 1999;284:65–71.
# Zahavi A. Decorative patterns and the evolution of art. New Scientist. 1978;19:182–184.
# Zaidel DW. Neuropsychology of Art: Neurological, Cognitive, and Evolutionary Perspectives. UK: Psychology Press; 2005.
# Zaidel DW. Neuroaesthetics. Amityville, NY: Baywood; 2009.
# Zak PJ, Kurzban R, Matzner WT. Oxytocin is associated with human trustworthiness. Horm Behav. 2005;48:522–527.
# Zeki S. A century of cerebral achromatopsia. Brain. 1990;113:1721–1777.

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-cef8011cb395> in <module>
# ----> 1 assert False, "DO NOT REMOVE THIS LINE"
#
# AssertionError: DO NOT REMOVE THIS LINE

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week08_assignment_2.ipynb
# git commit -a -m "Submitting the week 8 programming assignment"
# git push
# Out:
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	../practice.ipynb
# 	../week02/week02_inclass.ipynb
# 	../week04/week04_lookups.ipynb
# 	../week05_assignment_2.ipynb
# 	../week06/2019_nCoV_20200121_20200206.csv
# 	../week06/allergies.json
# 	../week06/output.csv
# 	../week06/week06_assignment_2copy.ipynb
# 	../week07-midterm/midterm-2021_copy.ipynb
# 	../week07-midterm/test-patients.csv
# 	week08_assignment_2-Copy1.ipynb
# 	week08_assignment_2copy1.ipynb
# 	../week09/
#
# nothing added to commit but untracked files present
# Everything up-to-date

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 8 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
